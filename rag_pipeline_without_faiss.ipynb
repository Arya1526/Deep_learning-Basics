# %%
import sys

# !{sys.executable} -m pip install \
langchain \
langchain-community \
langchain-groq \
sentence-transformers \
faiss-cpu \
pypdf

from langchain_community.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS

from langchain_groq import ChatGroq
from langchain.chains import RetrievalQA


pdf_path = "/Users/Aryaanil/Documents/survey cdc.pdf"


loader = PyPDFLoader(pdf_path)

documents = loader.load()


text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50
)

chunks = text_splitter.split_documents(documents)


embedding_model = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)


vector_store = FAISS.from_documents(
    chunks,
    embedding_model
)


retriever = vector_store.as_retriever(
    search_kwargs={"k": 3}
)


groq_api_key = "YOUR_GROQ_API_KEY"


llm = ChatGroq(
    groq_api_key=groq_api_key,
    model_name="llama3-8b-8192"
)


qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    retriever=retriever,
    chain_type="stuff"
)


questions = [
    "What is the main topic of the PDF?",
    "Explain one important concept from the notes.",
    "What tools or libraries are mentioned?",
    "Summarize the document in simple words.",
    "What are the key learning points?"
]


for question in questions:

    answer = qa_chain.run(question)

    print("\nQUESTION:")
    print(question)

    print("\nANSWER:")
    print(answer)

    print("\n" + "=" * 60)
# Out:
# Requirement already satisfied: langchain in /opt/anaconda3/lib/python3.12/site-packages (1.3.2)
# Requirement already satisfied: langchain-community in /opt/anaconda3/lib/python3.12/site-packages (0.4.2)
# Requirement already satisfied: langchain-groq in /opt/anaconda3/lib/python3.12/site-packages (1.1.2)
# Requirement already satisfied: sentence-transformers in /opt/anaconda3/lib/python3.12/site-packages (5.5.1)
# Collecting faiss-cpu
#   Using cached faiss_cpu-1.12.0.tar.gz (69 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: pypdf in /opt/anaconda3/lib/python3.12/site-packages (6.12.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain) (1.4.0)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.2 in /opt/anaconda3/lib/python3.12/site-packages (from langchain) (1.2.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /opt/anaconda3/lib/python3.12/site-packages (from langchain) (2.8.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-community) (3.10.5)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-community) (1.0.7)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-community) (0.8.5)
# Requirement already satisfied: numpy>=1.26.2 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-community) (2.14.1)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-community) (6.0.1)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-community) (2.34.2)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-community) (2.0.34)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-community) (8.2.3)
# Requirement already satisfied: groq<1.0.0,>=0.30.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-groq) (0.37.1)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in /opt/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (5.9.0)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /opt/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (1.16.4)
# Requirement already satisfied: torch>=1.11.0 in /opt/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (2.11.0)
# Requirement already satisfied: scikit-learn>=0.22.0 in /opt/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (1.5.1)
# Requirement already satisfied: scipy>=1.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (4.14.0)
# Requirement already satisfied: tqdm>=4.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (4.66.5)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.12/site-packages (from faiss-cpu) (24.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.11.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/anaconda3/lib/python3.12/site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/anaconda3/lib/python3.12/site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (0.27.0)
# Requirement already satisfied: sniffio in /opt/anaconda3/lib/python3.12/site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.3.0)
# Requirement already satisfied: click>=8.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (8.4.1)
# Requirement already satisfied: filelock>=3.10.0 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (2024.6.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (1.5.0)
# Requirement already satisfied: typer<0.26.0,>=0.20.0 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (0.25.1)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (1.1.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (0.0.15)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (0.16.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from langgraph<1.3.0,>=1.2.2->langchain) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from langgraph<1.3.0,>=1.2.2->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from langgraph<1.3.0,>=1.2.2->langchain) (0.3.15)
# Requirement already satisfied: xxhash>=3.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from langgraph<1.3.0,>=1.2.2->langchain) (3.7.0)
# Requirement already satisfied: orjson>=3.9.14 in /opt/anaconda3/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /opt/anaconda3/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.20.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.21.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.2.3)
# Requirement already satisfied: certifi>=2023.5.7 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2026.4.22)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn>=0.22.0->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn>=0.22.0->sentence-transformers) (3.5.0)
# Requirement already satisfied: setuptools<82 in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (75.1.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: regex>=2025.10.22 in /opt/anaconda3/lib/python3.12/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2026.5.9)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /opt/anaconda3/lib/python3.12/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /opt/anaconda3/lib/python3.12/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.12/site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/anaconda3/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain) (2.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in /opt/anaconda3/lib/python3.12/site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.2->langchain) (1.12.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->sentence-transformers) (1.5.0)
# Requirement already satisfied: rich>=13.8.0 in /opt/anaconda3/lib/python3.12/site-packages (from typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->sentence-transformers) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /opt/anaconda3/lib/python3.12/site-packages (from typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->sentence-transformers) (0.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->sentence-transformers) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.12/site-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->sentence-transformers) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->sentence-transformers) (0.1.0)
# Building wheels for collected packages: faiss-cpu
#   Building wheel for faiss-cpu (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Building wheel for faiss-cpu (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [8 lines of output]
#       running bdist_wheel
#       running build
#       running build_py
#       running build_ext
#       building 'faiss._swigfaiss' extension
#       swigging third-party/faiss/faiss/python/swigfaiss.i to third-party/faiss/faiss/python/swigfaiss_wrap.cpp
#       swig -python -c++ -Doverride= -doxygen -Ithird-party/faiss -I/private/var/folders/2q/c34xq8nn70lgm5zqqcds5x7m0000gn/T/pip-build-env-rw1nbwbn/overlay/lib/python3.12/site-packages/numpy/_core/include -Ithird-party/faiss -I/usr/local/include -o third-party/faiss/faiss/python/swigfaiss_wrap.cpp third-party/faiss/faiss/python/swigfaiss.i
#       error: command 'swig' failed: No such file or directory
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for faiss-cpu
# Failed to build faiss-cpu
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (faiss-cpu)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 6
#       3 get_ipython().system('{sys.executable} -m pip install  langchain  langchain-community  langchain-groq  sentence-transformers  faiss-cpu  pypdf')
#       5 from langchain_community.document_loaders import PyPDFLoader
# ----> 6 from langchain.text_splitter import RecursiveCharacterTextSplitter
#       8 from langchain_community.embeddings import HuggingFaceEmbeddings
#       9 from langchain_community.vectorstores import FAISS
#
# ModuleNotFoundError: No module named 'langchain.text_splitter'

# %%
import sys

# !{sys.executable} -m pip install \
langchain \
langchain-community \
langchain-text-splitters \
langchain-groq \
sentence-transformers \
faiss-cpu \
pypdf

from langchain_community.document_loaders import PyPDFLoader

from langchain_text_splitters import RecursiveCharacterTextSplitter

from langchain_community.embeddings import HuggingFaceEmbeddings

from langchain_community.vectorstores import FAISS

from langchain_groq import ChatGroq

from langchain.chains import RetrievalQA


pdf_path = "week_notes.pdf"


loader = PyPDFLoader(pdf_path)

documents = loader.load()


text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50
)

chunks = text_splitter.split_documents(documents)


embedding_model = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)


vector_store = FAISS.from_documents(
    chunks,
    embedding_model
)


retriever = vector_store.as_retriever(
    search_kwargs={"k": 3}
)


groq_api_key = "YOUR_GROQ_API_KEY"


llm = ChatGroq(
    groq_api_key=groq_api_key,
    model_name="llama3-8b-8192"
)


qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    retriever=retriever,
    chain_type="stuff"
)


questions = [
    "What is the main topic of the PDF?",
    "Explain one important concept from the notes.",
    "What tools or libraries are mentioned?",
    "Summarize the document in simple words.",
    "What are the key learning points?"
]


for question in questions:

    answer = qa_chain.run(question)

    print("\nQUESTION:")
    print(question)

    print("\nANSWER:")
    print(answer)

    print("\n" + "=" * 60)
# Out:
# Requirement already satisfied: langchain in /opt/anaconda3/lib/python3.12/site-packages (1.3.2)
# Requirement already satisfied: langchain-community in /opt/anaconda3/lib/python3.12/site-packages (0.4.2)
# Requirement already satisfied: langchain-text-splitters in /opt/anaconda3/lib/python3.12/site-packages (1.1.2)
# Requirement already satisfied: langchain-groq in /opt/anaconda3/lib/python3.12/site-packages (1.1.2)
# Requirement already satisfied: sentence-transformers in /opt/anaconda3/lib/python3.12/site-packages (5.5.1)
# Collecting faiss-cpu
#   Using cached faiss_cpu-1.12.0.tar.gz (69 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: pypdf in /opt/anaconda3/lib/python3.12/site-packages (6.12.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain) (1.4.0)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.2 in /opt/anaconda3/lib/python3.12/site-packages (from langchain) (1.2.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /opt/anaconda3/lib/python3.12/site-packages (from langchain) (2.8.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-community) (3.10.5)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-community) (1.0.7)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-community) (0.8.5)
# Requirement already satisfied: numpy>=1.26.2 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-community) (2.14.1)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-community) (6.0.1)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-community) (2.34.2)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-community) (2.0.34)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-community) (8.2.3)
# Requirement already satisfied: groq<1.0.0,>=0.30.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-groq) (0.37.1)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in /opt/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (5.9.0)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /opt/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (1.16.4)
# Requirement already satisfied: torch>=1.11.0 in /opt/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (2.11.0)
# Requirement already satisfied: scikit-learn>=0.22.0 in /opt/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (1.5.1)
# Requirement already satisfied: scipy>=1.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (4.14.0)
# Requirement already satisfied: tqdm>=4.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (4.66.5)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.12/site-packages (from faiss-cpu) (24.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.11.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/anaconda3/lib/python3.12/site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/anaconda3/lib/python3.12/site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (0.27.0)
# Requirement already satisfied: sniffio in /opt/anaconda3/lib/python3.12/site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.3.0)
# Requirement already satisfied: click>=8.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (8.4.1)
# Requirement already satisfied: filelock>=3.10.0 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (2024.6.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (1.5.0)
# Requirement already satisfied: typer<0.26.0,>=0.20.0 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (0.25.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (0.0.15)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (0.16.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from langgraph<1.3.0,>=1.2.2->langchain) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from langgraph<1.3.0,>=1.2.2->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from langgraph<1.3.0,>=1.2.2->langchain) (0.3.15)
# Requirement already satisfied: xxhash>=3.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from langgraph<1.3.0,>=1.2.2->langchain) (3.7.0)
# Requirement already satisfied: orjson>=3.9.14 in /opt/anaconda3/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /opt/anaconda3/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.20.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.21.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.2.3)
# Requirement already satisfied: certifi>=2023.5.7 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2026.4.22)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn>=0.22.0->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn>=0.22.0->sentence-transformers) (3.5.0)
# Requirement already satisfied: setuptools<82 in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (75.1.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: regex>=2025.10.22 in /opt/anaconda3/lib/python3.12/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2026.5.9)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /opt/anaconda3/lib/python3.12/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /opt/anaconda3/lib/python3.12/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.12/site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/anaconda3/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain) (2.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in /opt/anaconda3/lib/python3.12/site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.2->langchain) (1.12.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->sentence-transformers) (1.5.0)
# Requirement already satisfied: rich>=13.8.0 in /opt/anaconda3/lib/python3.12/site-packages (from typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->sentence-transformers) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /opt/anaconda3/lib/python3.12/site-packages (from typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->sentence-transformers) (0.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->sentence-transformers) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.12/site-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->sentence-transformers) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->sentence-transformers) (0.1.0)
# Building wheels for collected packages: faiss-cpu
#   Building wheel for faiss-cpu (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Building wheel for faiss-cpu (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [8 lines of output]
#       running bdist_wheel
#       running build
#       running build_py
#       running build_ext
#       building 'faiss._swigfaiss' extension
#       swigging third-party/faiss/faiss/python/swigfaiss.i to third-party/faiss/faiss/python/swigfaiss_wrap.cpp
#       swig -python -c++ -Doverride= -doxygen -Ithird-party/faiss -I/private/var/folders/2q/c34xq8nn70lgm5zqqcds5x7m0000gn/T/pip-build-env-gsivwjoa/overlay/lib/python3.12/site-packages/numpy/_core/include -Ithird-party/faiss -I/usr/local/include -o third-party/faiss/faiss/python/swigfaiss_wrap.cpp third-party/faiss/faiss/python/swigfaiss.i
#       error: command 'swig' failed: No such file or directory
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for faiss-cpu
# Failed to build faiss-cpu
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (faiss-cpu)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 15
#      11 from langchain_community.vectorstores import FAISS
#      13 from langchain_groq import ChatGroq
# ---> 15 from langchain.chains import RetrievalQA
#      18 pdf_path = "week_notes.pdf"
#      21 loader = PyPDFLoader(pdf_path)
#
# ModuleNotFoundError: No module named 'langchain.chains'

# %%
import sys

# !{sys.executable} -m pip install \
langchain \
langchain-community \
langchain-core \
langchain-text-splitters \
langchain-groq \
sentence-transformers \
faiss-cpu \
pypdf

from langchain_community.document_loaders import PyPDFLoader

from langchain_text_splitters import RecursiveCharacterTextSplitter

from langchain_community.embeddings import HuggingFaceEmbeddings

from langchain_community.vectorstores import FAISS

from langchain_groq import ChatGroq


pdf_path = "/Users/Aryaanil/Documents/survey cdc.pdf"


loader = PyPDFLoader(pdf_path)

documents = loader.load()


text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50
)

chunks = text_splitter.split_documents(documents)


embedding_model = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)


vector_store = FAISS.from_documents(
    chunks,
    embedding_model
)


retriever = vector_store.as_retriever(
    search_kwargs={"k": 3}
)


groq_api_key = "* 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"


llm = ChatGroq(
    groq_api_key=groq_api_key,
    model_name="llama3-8b-8192"
)


questions = [
    "What is the main topic of the PDF?",
    "Explain one important concept from the notes.",
    "What tools or libraries are mentioned?",
    "Summarize the document in simple words.",
    "What are the key learning points?"
]


for question in questions:

    docs = retriever.get_relevant_documents(question)

    context = "\n".join(
        [doc.page_content for doc in docs]
    )

    prompt = f"""
    Answer the question using the context below.

    Context:
    {context}

    Question:
    {question}
    """

    response = llm.invoke(prompt)

    print("\nQUESTION:")
    print(question)

    print("\nANSWER:")
    print(response.content)

    print("\n" + "=" * 60)
# Out:
# Requirement already satisfied: langchain in /opt/anaconda3/lib/python3.12/site-packages (1.3.2)
# Requirement already satisfied: langchain-community in /opt/anaconda3/lib/python3.12/site-packages (0.4.2)
# Requirement already satisfied: langchain-core in /opt/anaconda3/lib/python3.12/site-packages (1.4.0)
# Requirement already satisfied: langchain-text-splitters in /opt/anaconda3/lib/python3.12/site-packages (1.1.2)
# Requirement already satisfied: langchain-groq in /opt/anaconda3/lib/python3.12/site-packages (1.1.2)
# Requirement already satisfied: sentence-transformers in /opt/anaconda3/lib/python3.12/site-packages (5.5.1)
# Collecting faiss-cpu
#   Using cached faiss_cpu-1.12.0.tar.gz (69 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: pypdf in /opt/anaconda3/lib/python3.12/site-packages (6.12.2)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.2 in /opt/anaconda3/lib/python3.12/site-packages (from langchain) (1.2.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /opt/anaconda3/lib/python3.12/site-packages (from langchain) (2.8.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-community) (3.10.5)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-community) (1.0.7)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-community) (0.8.5)
# Requirement already satisfied: numpy>=1.26.2 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-community) (2.14.1)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-community) (6.0.1)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-community) (2.34.2)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-community) (2.0.34)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-community) (8.2.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-core) (0.0.15)
# Requirement already satisfied: packaging>=23.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-core) (24.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-core) (4.14.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-core) (0.16.0)
# Requirement already satisfied: groq<1.0.0,>=0.30.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-groq) (0.37.1)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in /opt/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (5.9.0)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /opt/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (1.16.4)
# Requirement already satisfied: torch>=1.11.0 in /opt/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (2.11.0)
# Requirement already satisfied: scikit-learn>=0.22.0 in /opt/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (1.5.1)
# Requirement already satisfied: scipy>=1.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: tqdm>=4.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (4.66.5)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.11.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/anaconda3/lib/python3.12/site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/anaconda3/lib/python3.12/site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (0.27.0)
# Requirement already satisfied: sniffio in /opt/anaconda3/lib/python3.12/site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.3.0)
# Requirement already satisfied: click>=8.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (8.4.1)
# Requirement already satisfied: filelock>=3.10.0 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (2024.6.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (1.5.0)
# Requirement already satisfied: typer<0.26.0,>=0.20.0 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (0.25.1)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/anaconda3/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (2.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from langgraph<1.3.0,>=1.2.2->langchain) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from langgraph<1.3.0,>=1.2.2->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from langgraph<1.3.0,>=1.2.2->langchain) (0.3.15)
# Requirement already satisfied: xxhash>=3.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from langgraph<1.3.0,>=1.2.2->langchain) (3.7.0)
# Requirement already satisfied: orjson>=3.9.14 in /opt/anaconda3/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /opt/anaconda3/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.20.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.21.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.2.3)
# Requirement already satisfied: certifi>=2023.5.7 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2026.4.22)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn>=0.22.0->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn>=0.22.0->sentence-transformers) (3.5.0)
# Requirement already satisfied: setuptools<82 in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (75.1.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: regex>=2025.10.22 in /opt/anaconda3/lib/python3.12/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2026.5.9)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /opt/anaconda3/lib/python3.12/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /opt/anaconda3/lib/python3.12/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.12/site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.14.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /opt/anaconda3/lib/python3.12/site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.2->langchain) (1.12.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->sentence-transformers) (1.5.0)
# Requirement already satisfied: rich>=13.8.0 in /opt/anaconda3/lib/python3.12/site-packages (from typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->sentence-transformers) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /opt/anaconda3/lib/python3.12/site-packages (from typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->sentence-transformers) (0.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->sentence-transformers) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.12/site-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->sentence-transformers) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->sentence-transformers) (0.1.0)
# Building wheels for collected packages: faiss-cpu
#   Building wheel for faiss-cpu (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Building wheel for faiss-cpu (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [8 lines of output]
#       running bdist_wheel
#       running build
#       running build_py
#       running build_ext
#       building 'faiss._swigfaiss' extension
#       swigging third-party/faiss/faiss/python/swigfaiss.i to third-party/faiss/faiss/python/swigfaiss_wrap.cpp
#       swig -python -c++ -Doverride= -doxygen -Ithird-party/faiss -I/private/var/folders/2q/c34xq8nn70lgm5zqqcds5x7m0000gn/T/pip-build-env-gp1_1wdr/overlay/lib/python3.12/site-packages/numpy/_core/include -Ithird-party/faiss -I/usr/local/include -o third-party/faiss/faiss/python/swigfaiss_wrap.cpp third-party/faiss/faiss/python/swigfaiss.i
#       error: command 'swig' failed: No such file or directory
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for faiss-cpu
# Failed to build faiss-cpu
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (faiss-cpu)
# /var/folders/2q/c34xq8nn70lgm5zqqcds5x7m0000gn/T/ipykernel_22368/735670867.py:32: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   embedding_model = HuggingFaceEmbeddings(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/langchain_community/vectorstores/faiss.py:56, in dependable_faiss_import(no_avx2)
#      55     else:
# ---> 56         import faiss
#      57 except ImportError:
#
# ModuleNotFoundError: No module named 'faiss'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 37
#      29 chunks = text_splitter.split_documents(documents)
#      32 embedding_model = HuggingFaceEmbeddings(
#      33     model_name="sentence-transformers/all-MiniLM-L6-v2"
#      34 )
# ---> 37 vector_store = FAISS.from_documents(
#      38     chunks,
#      39     embedding_model
#      40 )
#      43 retriever = vector_store.as_retriever(
#      44     search_kwargs={"k": 3}
#      45 )
#      48 groq_api_key = "* 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"
#
# File /opt/anaconda3/lib/python3.12/site-packages/langchain_core/vectorstores/base.py:814, in VectorStore.from_documents(cls, documents, embedding, **kwargs)
#     811     if any(ids):
#     812         kwargs["ids"] = ids
# --> 814 return cls.from_texts(texts, embedding, metadatas=metadatas, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/langchain_community/vectorstores/faiss.py:1044, in FAISS.from_texts(cls, texts, embedding, metadatas, ids, **kwargs)
#    1025 """Construct FAISS wrapper from raw documents.
#    1026
#    1027 This is a user friendly interface that:
#    (...)
#    1041         faiss = FAISS.from_texts(texts, embeddings)
#    1042 """
#    1043 embeddings = embedding.embed_documents(texts)
# -> 1044 return cls.__from(
#    1045     texts,
#    1046     embeddings,
#    1047     embedding,
#    1048     metadatas=metadatas,
#    1049     ids=ids,
#    1050     **kwargs,
#    1051 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/langchain_community/vectorstores/faiss.py:996, in FAISS.__from(cls, texts, embeddings, embedding, metadatas, ids, normalize_L2, distance_strategy, **kwargs)
#     984 @classmethod
#     985 def __from(
#     986     cls,
#    (...)
#     994     **kwargs: Any,
#     995 ) -> FAISS:
# --> 996     faiss = dependable_faiss_import()
#     997     if distance_strategy == DistanceStrategy.MAX_INNER_PRODUCT:
#     998         index = faiss.IndexFlatIP(len(embeddings[0]))
#
# File /opt/anaconda3/lib/python3.12/site-packages/langchain_community/vectorstores/faiss.py:58, in dependable_faiss_import(no_avx2)
#      56         import faiss
#      57 except ImportError:
# ---> 58     raise ImportError(
#      59         "Could not import faiss python package. "
#      60         "Please install it with `pip install faiss-gpu` (for CUDA supported GPU) "
#      61         "or `pip install faiss-cpu` (depending on Python version)."
#      62     )
#      63 return faiss
#
# ImportError: Could not import faiss python package. Please install it with `pip install faiss-gpu` (for CUDA supported GPU) or `pip install faiss-cpu` (depending on Python version).

# %%
import sys

# !{sys.executable} -m pip install \
langchain-community \
langchain-text-splitters \
langchain-groq \
langchain-huggingface \
sentence-transformers \
pypdf \
scikit-learn

from langchain_community.document_loaders import PyPDFLoader

from langchain_text_splitters import RecursiveCharacterTextSplitter

from langchain_huggingface import HuggingFaceEmbeddings

from sklearn.metrics.pairwise import cosine_similarity

from langchain_groq import ChatGroq

import numpy as np


pdf_path = "/Users/Aryaanil/Documents/survey cdc.pdf"


loader = PyPDFLoader(pdf_path)

documents = loader.load()


text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50
)

chunks = text_splitter.split_documents(documents)


texts = [doc.page_content for doc in chunks]


embedding_model = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)


document_embeddings = embedding_model.embed_documents(texts)

document_embeddings = np.array(document_embeddings)


groq_api_key = "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"


llm = ChatGroq(
    groq_api_key=groq_api_key,
    model_name="llama-3.3-70b-versatile"
)


questions = [
    "What is the main topic of the PDF?",
    "Explain one important concept from the notes.",
    "What tools or libraries are mentioned?",
    "Summarize the document in simple words.",
    "What are the key learning points?"
]


def retrieve_documents(query, k=3):

    query_embedding = embedding_model.embed_query(query)

    similarity_scores = cosine_similarity(
        [query_embedding],
        document_embeddings
    )[0]

    top_indices = similarity_scores.argsort()[::-1][:k]

    return [texts[i] for i in top_indices]


for question in questions:

    retrieved_docs = retrieve_documents(question)

    context = "\n".join(retrieved_docs)

    prompt = f"""
    Answer the question using the context below.

    Context:
    {context}

    Question:
    {question}
    """

    response = llm.invoke(prompt)

    print("\nQUESTION:")
    print(question)

    print("\nANSWER:")
    print(response.content)

    print("\n" + "=" * 60)
# Out:
# Requirement already satisfied: langchain-community in /opt/anaconda3/lib/python3.12/site-packages (0.4.2)
# Requirement already satisfied: langchain-text-splitters in /opt/anaconda3/lib/python3.12/site-packages (1.1.2)
# Requirement already satisfied: langchain-groq in /opt/anaconda3/lib/python3.12/site-packages (1.1.2)
# Requirement already satisfied: langchain-huggingface in /opt/anaconda3/lib/python3.12/site-packages (1.2.2)
# Requirement already satisfied: sentence-transformers in /opt/anaconda3/lib/python3.12/site-packages (5.5.1)
# Requirement already satisfied: pypdf in /opt/anaconda3/lib/python3.12/site-packages (6.12.2)
# Requirement already satisfied: scikit-learn in /opt/anaconda3/lib/python3.12/site-packages (1.5.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-community) (3.10.5)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-community) (1.0.7)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-community) (1.4.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-community) (0.8.5)
# Requirement already satisfied: numpy>=1.26.2 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-community) (2.14.1)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-community) (6.0.1)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-community) (2.34.2)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-community) (2.0.34)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-community) (8.2.3)
# Requirement already satisfied: groq<1.0.0,>=0.30.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-groq) (0.37.1)
# Requirement already satisfied: huggingface-hub<2.0.0,>=0.33.4 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-huggingface) (1.16.4)
# Requirement already satisfied: tokenizers<1.0.0,>=0.19.1 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-huggingface) (0.22.2)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in /opt/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (5.9.0)
# Requirement already satisfied: torch>=1.11.0 in /opt/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (2.11.0)
# Requirement already satisfied: scipy>=1.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (4.14.0)
# Requirement already satisfied: tqdm>=4.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (4.66.5)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.11.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/anaconda3/lib/python3.12/site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/anaconda3/lib/python3.12/site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /opt/anaconda3/lib/python3.12/site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (2.8.2)
# Requirement already satisfied: sniffio in /opt/anaconda3/lib/python3.12/site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.3.0)
# Requirement already satisfied: click>=8.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (8.4.1)
# Requirement already satisfied: filelock>=3.10.0 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (2024.6.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (1.5.0)
# Requirement already satisfied: packaging>=20.9 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (24.1)
# Requirement already satisfied: typer<0.26.0,>=0.20.0 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.25.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.0.15)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.16.0)
# Requirement already satisfied: orjson>=3.9.14 in /opt/anaconda3/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in /opt/anaconda3/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.21.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.2.3)
# Requirement already satisfied: certifi>=2023.5.7 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2026.4.22)
# Requirement already satisfied: setuptools<82 in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (75.1.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: regex>=2025.10.22 in /opt/anaconda3/lib/python3.12/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2026.5.9)
# Requirement already satisfied: safetensors>=0.4.3 in /opt/anaconda3/lib/python3.12/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.12/site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/anaconda3/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (2.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (2.20.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from typer<0.26.0,>=0.20.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (1.5.0)
# Requirement already satisfied: rich>=13.8.0 in /opt/anaconda3/lib/python3.12/site-packages (from typer<0.26.0,>=0.20.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /opt/anaconda3/lib/python3.12/site-packages (from typer<0.26.0,>=0.20.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.12/site-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.1.0)
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# QUESTION:
# What is the main topic of the PDF?
#
# ANSWER:
# The main topic of the survey appears to be related to academic and student-related matters, specifically focusing on the student community, with an emphasis on stress and how students handle difficult situations.
#
# ============================================================
#
# QUESTION:
# Explain one important concept from the notes.
#
# ANSWER:
# One important concept from the notes is the idea of assessing and measuring happiness in daily life. This is reflected in question 5 of Section B, which asks respondents to rate their happiness on a scale of 1-10. This concept is significant because it acknowledges that happiness is a subjective and personal experience that can vary from person to person, and that understanding an individual's level of happiness can provide insight into their overall emotional well-being.
#
# ============================================================
#
# QUESTION:
# What tools or libraries are mentioned?
#
# ANSWER:
# None, the context provided does not mention any specific tools or libraries. It appears to be a survey questionnaire focused on academic and student-related matters, happiness, and emotional well-being.
#
# ============================================================
#
# QUESTION:
# Summarize the document in simple words.
#
# ANSWER:
# The document talks about people's feelings. Most people are moderately to very happy in their daily lives and feel they have support when needed. However, many people (45%) feel stressed sometimes, and some (29%) feel stressed often. This means that while people are generally happy, they also experience stress in their lives.
#
# ============================================================
#
# QUESTION:
# What are the key learning points?
#
# ANSWER:
# The key learning points based on the provided context are:
#
# 1. **Survey demographics**: The survey respondents are predominantly students (with only 1.5% being self-employed), making the findings highly relevant to the student population.
# 2. **Stress and coping mechanisms**: The survey inquires about the frequency of feeling stressed (question 9) and the ability to handle difficult situations (question 10), indicating an interest in understanding students' mental health and resilience.
# 3. **Emotional expression and support**: Question 15 explores students' comfort levels with sharing their thoughts and feelings with close individuals, highlighting the importance of social support networks.
# 4. **Sleep habits**: The survey also collects data on students' sleep patterns (question 1 in Section E), which is a crucial aspect of overall health and well-being.
#
# These key points suggest that the survey is focused on understanding students' mental health, emotional well-being, and lifestyle habits, with a particular emphasis on stress, coping mechanisms, social support, and sleep patterns.
#
# ============================================================

# %%
import tensorflow as tf
import numpy as np

X = np.array([[1], [2], [3], [4], [5]], dtype=float)
y = np.array([[1], [4], [7], [10], [13]], dtype=float)

model = tf.keras.Sequential([
    tf.keras.layers.Dense(1, input_shape=(1,))
])

model.compile(optimizer='adam', loss='mse')

for epoch in range(300):
    model.fit(X, y, epochs=1, verbose=0)

    if (epoch + 1) % 50 == 0:
        loss = model.evaluate(X, y, verbose=0)
        print(f"Epoch {epoch+1}, Loss: {loss}")

prediction = model.predict(np.array([[10]], dtype=float))

print("\nPrediction for x = 10:")
print(prediction)
# Out:
# Epoch 50, Loss: 23.161306381225586
# Epoch 100, Loss: 21.29294204711914
# Epoch 150, Loss: 19.550006866455078
# Epoch 200, Loss: 17.927059173583984
# Epoch 250, Loss: 16.41866683959961
# Epoch 300, Loss: 15.019495964050293
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
#
# Prediction for x = 10:
# [[12.750411]]
